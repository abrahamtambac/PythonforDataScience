# %%
import pandas as pd

# %%
import numpy as np

# %%
df_brics = pd.read_csv("../../data/input/brics.csv")
df_brics
# Out:
#   Unnamed: 0       country    capital    area  population
# 0         BR        Brazil   Brasilia   8.516      200.40
# 1         RU        Russia     Moscow  17.100      143.50
# 2         IN         India  New Delhi   3.286     1252.00
# 3         CH         China    Beijing   9.597     1357.00
# 4         SA  South Africa   Pretoria   1.221       52.98

# %%
## cek kolumn dan row index
df_brics.columns
# Out:
# Index(['Unnamed: 0', 'country', 'capital', 'area', 'population'], dtype='object')

# %%
## menghitung index pada row yang ada dalam tabel
df_brics.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
## pindahkan unnamed = 0 ke row's index
brics_detail = df_brics.set_index("Unnamed: 0")
brics_detail
# Out:
#                  country    capital    area  population
# Unnamed: 0
# BR                Brazil   Brasilia   8.516      200.40
# RU                Russia     Moscow  17.100      143.50
# IN                 India  New Delhi   3.286     1252.00
# CH                 China    Beijing   9.597     1357.00
# SA          South Africa   Pretoria   1.221       52.98

# %%
brics_detail.reset_index()
# Out:
#   Unnamed: 0       country    capital    area  population
# 0         BR        Brazil   Brasilia   8.516      200.40
# 1         RU        Russia     Moscow  17.100      143.50
# 2         IN         India  New Delhi   3.286     1252.00
# 3         CH         China    Beijing   9.597     1357.00
# 4         SA  South Africa   Pretoria   1.221       52.98

# %%
brics_ = df_brics.set_index("country")
brics_
# Out:
#              Unnamed: 0    capital    area  population
# country
# Brazil               BR   Brasilia   8.516      200.40
# Russia               RU     Moscow  17.100      143.50
# India                IN  New Delhi   3.286     1252.00
# China                CH    Beijing   9.597     1357.00
# South Africa         SA   Pretoria   1.221       52.98

# %%
#Subset informasi yang ada pada china
brics_.loc["China"]
# Out:
# Unnamed: 0         CH
# capital       Beijing
# area            9.597
# population     1357.0
# Name: China, dtype: object

# %%
homeless = pd.read_csv("../../data/input/homelessness.csv")
homeless
# Out:
#     Unnamed: 0              region                 state  individuals  \
# 0            0  East South Central               Alabama       2570.0
# 1            1             Pacific                Alaska       1434.0
# 2            2            Mountain               Arizona       7259.0
# 3            3  West South Central              Arkansas       2280.0
# 4            4             Pacific            California     109008.0
# 5            5            Mountain              Colorado       7607.0
# 6            6         New England           Connecticut       2280.0
# 7            7      South Atlantic              Delaware        708.0
# 8            8      South Atlantic  District of Columbia       3770.0
# 9            9      South Atlantic               Florida      21443.0
# 10          10      South Atlantic               Georgia       6943.0
# 11          11             Pacific                Hawaii       4131.0
# ...

# %%
# pindahkan region menjadi row index 
homeless_region = homeless.set_index(["region"])
homeless_region
# Out:
#                     Unnamed: 0                 state  individuals  \
# region
# East South Central           0               Alabama       2570.0
# Pacific                      1                Alaska       1434.0
# Mountain                     2               Arizona       7259.0
# West South Central           3              Arkansas       2280.0
# Pacific                      4            California     109008.0
# Mountain                     5              Colorado       7607.0
# New England                  6           Connecticut       2280.0
# South Atlantic               7              Delaware        708.0
# South Atlantic               8  District of Columbia       3770.0
# South Atlantic               9               Florida      21443.0
# South Atlantic              10               Georgia       6943.0
# Pacific                     11                Hawaii       4131.0
# Mountain                    12                 Idaho       1297.0
# ...
