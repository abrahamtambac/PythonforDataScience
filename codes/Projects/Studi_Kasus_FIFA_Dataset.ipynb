# %% [markdown]
# # Studi Kasus FIFA Dataset
#
# 1. Import data FIFA atau FIFA_completed (data lebih kompleks), bisa di pilih salah satunya.
# 2. Lakukan langkah awal Exploratory Data Analysis dengan melihat summary statistics yang ada pada dataframe. # Gunakan method info dan describe
# 3. Perlihatkan 10 data pertama menggunakan method head
# 4. Perlihatkan 10 data terakhir menggunakan method tail
# 5. Pilih 10 column yang menurut anda paling relevan (dengan teknik subsetting [[ ]]) dan buat variabel baru
# 6. Dari column yang sudah di pilih analisa beberapa columns, siapa yang mempunyai nilai tertinggi (e.g: rating/salary/passing/dribbling/etc.)
# 7. Analisa juga siapa yang mempunyai nilai terendah dari beberapa columns tersebut
# 8. Analisa pada setiap columns nilai rata-rata dan nilai tengah
# 9. Cari data pemain yang ingin anda pilih dan perlihatkan keseluruhan data dengan teknik subsetting .iloc / .loc
# 10. Tampilkan plot sederhana yang sudah tersedia pada pandas library. Gunakan .plot() pada column yang disubset (e.g: fifa_data["rating"].plot() dan terapkan pada beberapa column yang telah dipilih

# %%
# FIFA Dataset
import pandas as pd
fifa_dataset = pd.read_csv("../../data/input/FIFA_dirty_dataset.csv", index_col = 0).head(6)
fifa_dataset
# Out:
#                            name   rating  position   height    foot   rare  \
# id
# 1001               Gábor Király       69        GK      191   Right      0
# 100143             Frederik Boi       65         M      184   Right      0
# 100264          Tomasz Szewczuk       57         A      185   Right      0
# 100325   Steeve Joseph-Reinette       63         D      180    Left      0
# 100326             Kamel Chafni       72         M      181   Right      0
# 100329           Abdoulaye Faye       72         D      187   Right      1
#
#         pace  shooting  passing  dribbling  defending  heading  diving  \
# id
# 1001                                                                70
# 100143    61        65       63         59         62       62
# 100264    65        54       43         53         55       74
# 100325    68        38       51         46         64       71
# 100326    75        64       67         72         57       66
# ...

# %%
fifa_dataset_tail = pd.read_csv("../../data/input/FIFA_dirty_dataset.csv", index_col = 0).tail(10)
fifa_dataset_tail
# Out:
#                     name   rating  position   height    foot   rare  pace  \
# id
# 9722    Nicolai Stokholm       67         M      182   Right      0    59
# 9723        Camel Meriem       71         M      174   Right      0    58
# 9751         Gábor Babos       71        GK      196   Right      1
# 9771    Orlando Engelaar       73         M      196    Left      1    38
# 9799   Pierre-Alain Frau       73         A      175   Right      1    79
# 9801     Danijel Ljuboja       73         A      189    Left      1    62
# 9805       Craig Bellamy       79         A      175   Right      0    80
# 9807       Michel Breuer       68         D      183   Right      0    61
# 9815         Gill Swerts       65         D      179   Right      0    65
# 9913         Mehdi Nafti       69         M      179   Right      0    55
#
#       shooting  passing  dribbling  defending  heading  diving  handling  \
# id
# 9722        67       71         56         70       70
# ...

# %%
fifa_dataset["rating"].mode()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080             try:
# -> 3081                 return self._engine.get_loc(casted_key)
#    3082             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'rating'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# Out:
#                     name   rating  position   height    foot   rare  pace  \
# id
# 9722    Nicolai Stokholm       67         M      182   Right      0    59
# 9723        Camel Meriem       71         M      174   Right      0    58
# 9751         Gábor Babos       71        GK      196   Right      1
# 9771    Orlando Engelaar       73         M      196    Left      1    38
# 9799   Pierre-Alain Frau       73         A      175   Right      1    79
# 9801     Danijel Ljuboja       73         A      189    Left      1    62
# 9805       Craig Bellamy       79         A      175   Right      0    80
# 9807       Michel Breuer       68         D      183   Right      0    61
# 9815         Gill Swerts       65         D      179   Right      0    65
# 9913         Mehdi Nafti       69         M      179   Right      0    55
#
#       shooting  passing  dribbling  defending  heading  diving  handling  \
# id
# 9722        67       71         56         70       70
# ...
